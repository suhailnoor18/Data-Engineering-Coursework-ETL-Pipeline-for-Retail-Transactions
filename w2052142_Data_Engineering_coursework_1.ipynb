# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer = pd.read_csv('/content/Customer.csv')
customer.head()
# Out:
#   customer ID customer_name   Customer Age Gender Marital status
# 0          c1      Hargrave           53.0   Male            Yes
# 1          c2          Hill           53.0   Male             No
# 2          c3          Onio           41.0   Male             No
# 3          c4          Boni           41.0   Male            Yes
# 4          c5      Mitchell           75.0   Male            Yes

# %%
sales = pd.read_csv('/content/Sales.csv')
sales.head()
# Out:
#    Order_id customer ID product_id  Unit Price Purchase Date   Payment Method
# 0         1          c1       P001      791.19     3/20/2024      Credit Card
# 1         2          c2       P002      247.03     4/20/2024      Credit Card
# 2         3          c3       P003      463.96    10/17/2023  Bank Withdrawal
# 3         4          c4       P004      791.19      8/9/2024  Bank Withdrawal
# 4         5          c5       P005       20.75     5/21/2024      Credit Card

# %%
products = pd.read_csv('/content/product.csv')
products.head()
# Out:
#   product_id Product_name   Product Quantity Product country Shipping Type
# 0       P001   Smartphone                6.0          France      Standard
# 1       P002       Tablet                6.0           Spain     Overnight
# 2       P003       Laptop                8.0          France       Express
# 3       P004   Smartphone                6.0          France     Overnight
# 4       P005   Smartphone                6.0           Spain       Express

# %% [markdown]
# 1a.

# %%
#Number of Data points for Customer
datapointsC = len(customer)
datapointsC
# Out:
# 599

# %%
#Number of Data points for sales
datapointsS = len(sales)
datapointsS
# Out:
# 599

# %%
#Number of data points for products
datapointsP = len(products)
datapointsP
# Out:
# 599

# %% [markdown]
# **1b.**

# %%
#name of attributes for customer information
customer_attribute = customer.columns
print(customer_attribute)
# Out:
# Index(['customer ID', 'customer_name', ' Customer Age', 'Gender',
#        'Marital status'],
#       dtype='object')

# %%
#name of attributes for sales transactions
sales_attribute = sales.columns
print(sales_attribute)
# Out:
# Index(['Order_id', 'customer ID', 'product_id', 'Unit Price', 'Purchase Date',
#        'Payment Method'],
#       dtype='object')

# %%
#name of attributes for inventory management data
products_attribute = products.columns
print(products_attribute)
# Out:
# Index(['product_id', 'Product_name', ' Product Quantity', 'Product country',
#        'Shipping Type'],
#       dtype='object')

# %% [markdown]
# **1C.**

# %%
#customer type of attributes
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer ID     599 non-null    object
#  1   customer_name   599 non-null    object
#  2    Customer Age   582 non-null    float64
#  3   Gender          599 non-null    object
#  4   Marital status  599 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 23.5+ KB

# %%
#sales type of attributes
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_id        599 non-null    int64
#  1   customer ID     599 non-null    object
#  2   product_id      599 non-null    object
#  3   Unit Price      584 non-null    float64
#  4   Purchase Date   599 non-null    object
#  5   Payment Method  582 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 28.2+ KB

# %%
#products type of attributes
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         599 non-null    object
#  1   Product_name       599 non-null    object
#  2    Product Quantity  580 non-null    float64
#  3   Product country    586 non-null    object
#  4   Shipping Type      599 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 23.5+ KB

# %% [markdown]
# **1D.**

# %%
#number of missing values for customer attributes
customer_missingvalues = customer.isnull().sum()
customer_missingvalues
# Out:
# customer ID        0
# customer_name      0
#  Customer Age     17
# Gender             0
# Marital status     0
# dtype: int64

# %%
#number of missing values for sales attributes
sales_missingvalues = sales.isnull().sum()
sales_missingvalues
# Out:
# Order_id           0
# customer ID        0
# product_id         0
# Unit Price        15
# Purchase Date      0
# Payment Method    17
# dtype: int64

# %%
#number of missing values for products attributes
products_missingvalues = products.isnull().sum()
products_missingvalues
# Out:
# product_id            0
# Product_name          0
#  Product Quantity    19
# Product country      13
# Shipping Type         0
# dtype: int64

# %% [markdown]
# **1E.**

# %%
#Entry errors for numerical values in customer file
customer[' Customer Age'].describe()
# Out:
# count    582.000000
# mean      49.115120
# std       18.407478
# min       18.000000
# 25%       33.000000
# 50%       50.000000
# 75%       64.000000
# max       80.000000
# Name:  Customer Age, dtype: float64

# %%
#Entry errors for categorical values in customer file
print(customer['Gender'].unique())
# Out:
# ['Male' 'Female']

# %%
print(customer['Marital status'].unique())
# Out:
# ['Yes' 'No']

# %%
#Entry errors for product numerical  files
products[' Product Quantity'].describe()
# Out:
# count    580.000000
# mean      14.191379
# std       35.868060
# min      -24.000000
# 25%        2.000000
# 50%        6.000000
# 75%       12.000000
# max      432.000000
# Name:  Product Quantity, dtype: float64

# %%
#Entry errors for categorical values in product file
print(products['Product_name'].unique())
# Out:
# ['Smartphone' 'Tablet' 'Laptop' 'Smartwatch']

# %%
print(products['Product country'].unique())
# Out:
# ['France' 'Spain' 'Germany' nan]

# %%
#Entry errors for numerical values in sales file
sales['Unit Price'].describe()
# Out:
# count    584.000000
# mean     481.825068
# std      316.269875
# min       20.750000
# 25%      247.030000
# 50%      463.960000
# 75%      791.190000
# max      844.830000
# Name: Unit Price, dtype: float64

# %%
#Entry errors for categorical values in sales file
Saleslist = sales['Purchase Date'].unique().tolist()
print(Saleslist)
# Out:
# ['3/20/2024', '4/20/2024', '10/17/2023', '8/9/2024', '5/21/2024', '5/26/2024', '1/30/2024', '6/24/2024', '10/3/2023', '1/1/2024', '6/25/2024', '11/7/2023', '9/25/2023', '7/7/2024', '3/18/2024', '1/2/2024', '5/18/2024', '9/2/2024', '7/23/2024', '3/14/2024', '7/21/2024', '12/2/2023', '4/27/2024', '7/10/2024', '1/29/2024', '8/28/2024', '11/28/2023', '11/30/2023', '2/27/2024', '1/21/2024', '9/3/2024', '1/12/2024', '9/24/2023', '3/25/2024', '10/12/2023', '1/28/2024', '7/8/2024', '7/29/2024', '8/17/2024', '9/23/2024', '8/31/2024', '10/16/2023', '6/26/2024', '7/16/2024', '3/5/2024', '12/11/2023', '10/28/2023', '8/3/2024', '12/20/2023', '5/8/2024', '10/22/2023', '3/28/2024', '6/12/2024', '2/22/2024', '6/27/2024', '9/28/2023', '12/7/2023', '10/25/2023', '3/23/2024', '4/25/2024', '2/28/2024', '7/13/2024', '12/30/2023', '11/29/2023', '6/17/2024', '7/11/2024', '9/12/2024', '11/6/2023', '12/26/2023', '5/14/2024', '10/24/2023', '9/15/2024', '1/3/2024', '8/18/2024', '10/11/2023', '5/2/2024', '7/1/2
# ...

# %%
print(sales['Payment Method'].unique())
# Out:
# ['Credit Card' 'Bank Withdrawal' nan 'Mailed Check']

# %% [markdown]
# **1F.**

# %%
#Heatmap to check missing values for customer file
sns.heatmap(customer.isnull(),cbar=False,cmap='viridis')
plt.title('Customer Missing Values')
# Out:
# Text(0.5, 1.0, 'Customer Missing Values')

# %%
#Heatmap to check missing values for sales file
sns.heatmap(sales.isnull(),cbar=False,cmap='viridis')
plt.title('Sales Missing Values')
# Out:
# Text(0.5, 1.0, 'Sales Missing Values')

# %%
#Heatmap to check missing values for products file
sns.heatmap(products.isnull(),cbar=False,cmap='viridis')
plt.title('Products Missing Values')
# Out:
# Text(0.5, 1.0, 'Products Missing Values')

# %% [markdown]
# **Task 02**

# %% [markdown]
# **2.1**

# %%
#merging
S_customer = pd.merge(sales,customer,on='customer ID',how ='outer')
final_dataset = pd.merge(S_customer,products,on='product_id',how='outer')
final_dataset
# Out:
#      Order_id customer ID product_id  Unit Price Purchase Date  \
# 0           1          c1       P001      791.19     3/20/2024
# 1           2          c2       P002      247.03     4/20/2024
# 2           3          c3       P003      463.96    10/17/2023
# 3           4          c4       P004      791.19      8/9/2024
# 4           5          c5       P005       20.75     5/21/2024
# ..        ...         ...        ...         ...           ...
# 594       595        c595       P595      247.03      3/8/2024
# 595       596        c596       P596      463.96     12/8/2023
# 596       597        c597       P597      844.83      6/1/2024
# 597       598        c598       P598      791.19     6/18/2024
# 598       599        c599       P599       20.75      7/9/2024
#
#       Payment Method customer_name   Customer Age  Gender Marital status  \
# 0        Credit Card      Hargrave           53.0    Male            Yes
# ...

# %% [markdown]
# **2.2**

# %%
#data cleaning procedures
#converts data type of customer age column to an integer
customer[' Customer Age'] = customer[' Customer Age'].fillna(0).astype(int)

# %%
final_dataset[' Customer Age'] = final_dataset[' Customer Age'].fillna(0).astype(int)

# %%
final_dataset[' Product Quantity'] = final_dataset[' Product Quantity'].fillna(0).astype(int)

# %%
#data cleaning procedures
#dealing with outliers
PQ_dataset = final_dataset[' Product Quantity']

plt.figure(figsize=(12,8))
sns.boxplot(x=PQ_dataset)
plt.title('Box plot of Product Quantity')
plt.xlabel(' Product Quantity')
plt.show()

# %%
Q1 = final_dataset[' Product Quantity'].quantile(0.25)
Q3 = final_dataset[' Product Quantity'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter data to exclude outliers
filtered_PQ_dataset = final_dataset[(final_dataset[' Product Quantity'] >= lower_bound) & (final_dataset[' Product Quantity'] <= upper_bound)]

# %%
plt.figure(figsize=(12, 8))  # Adjust figure size if needed
sns.boxplot(x=filtered_PQ_dataset[' Product Quantity'])
plt.title('Box Plot of Product Quantity after removing outleirs')
plt.xlabel(' Product Quantity')
plt.show()

# %%
column_rename =  {'Shipping Type': ' Delivery Method'}
final_dataset = final_dataset.rename(columns=column_rename)
final_dataset
# Out:
#      Order_id customer ID product_id  Unit Price Purchase Date  \
# 0           1          c1       P001      791.19     3/20/2024
# 1           2          c2       P002      247.03     4/20/2024
# 2           3          c3       P003      463.96    10/17/2023
# 3           4          c4       P004      791.19      8/9/2024
# 4           5          c5       P005       20.75     5/21/2024
# ..        ...         ...        ...         ...           ...
# 594       595        c595       P595      247.03      3/8/2024
# 595       596        c596       P596      463.96     12/8/2023
# 596       597        c597       P597      844.83      6/1/2024
# 597       598        c598       P598      791.19     6/18/2024
# 598       599        c599       P599       20.75      7/9/2024
#
#       Payment Method customer_name   Customer Age  Gender Marital status  \
# 0        Credit Card      Hargrave             53    Male            Yes
# ...

# %%
column_rename =  {'Purchase Date': ' Aqcuisition Date'}
final_dataset = final_dataset.rename(columns=column_rename)
final_dataset
# Out:
#      Order_id customer ID product_id  Unit Price  Aqcuisition Date  \
# 0           1          c1       P001      791.19         3/20/2024
# 1           2          c2       P002      247.03         4/20/2024
# 2           3          c3       P003      463.96        10/17/2023
# 3           4          c4       P004      791.19          8/9/2024
# 4           5          c5       P005       20.75         5/21/2024
# ..        ...         ...        ...         ...               ...
# 594       595        c595       P595      247.03          3/8/2024
# 595       596        c596       P596      463.96         12/8/2023
# 596       597        c597       P597      844.83          6/1/2024
# 597       598        c598       P598      791.19         6/18/2024
# 598       599        c599       P599       20.75          7/9/2024
#
#       Payment Method customer_name   Customer Age  Gender Marital status  \
# 0        Credit Card      Hargrave             53    Male            Yes
# ...

# %%
#handling of missing values
customer[' Customer Age'].fillna(customer[' Customer Age'].mean(), inplace=True)
# Out:
# <ipython-input-39-89d7b5cdc8b6>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customer[' Customer Age'].fillna(customer[' Customer Age'].mean(), inplace=True)

# %%
#number of missing values for customer attributes
customer_missingvalues = customer.isnull().sum()
customer_missingvalues
# Out:
# customer ID       0
# customer_name     0
#  Customer Age     0
# Gender            0
# Marital status    0
# dtype: int64

# %%
sales['Unit Price'].fillna(sales['Unit Price'].mean(), inplace=True)
sales['Payment Method'].fillna(sales['Payment Method'].mode()[0], inplace=True)
# Out:
# <ipython-input-41-4e67090ac124>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sales['Unit Price'].fillna(sales['Unit Price'].mean(), inplace=True)
# <ipython-input-41-4e67090ac124>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
#number of missing values for sales attributes
sales_missingvalues = sales.isnull().sum()
sales_missingvalues
# Out:
# Order_id          0
# customer ID       0
# product_id        0
# Unit Price        0
# Purchase Date     0
# Payment Method    0
# dtype: int64

# %%
products[' Product Quantity'].fillna(products[' Product Quantity'].mean(), inplace=True)
products['Product country'].fillna(products['Product country'].mode()[0], inplace=True)
# Out:
# <ipython-input-43-11b730886104>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products[' Product Quantity'].fillna(products[' Product Quantity'].mean(), inplace=True)
# <ipython-input-43-11b730886104>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
#number of missing values for products attributes
products_missingvalues = products.isnull().sum()
products_missingvalues
# Out:
# product_id           0
# Product_name         0
#  Product Quantity    0
# Product country      0
# Shipping Type        0
# dtype: int64

# %%
final_dataset
# Out:
#      Order_id customer ID product_id  Unit Price  Aqcuisition Date  \
# 0           1          c1       P001      791.19         3/20/2024
# 1           2          c2       P002      247.03         4/20/2024
# 2           3          c3       P003      463.96        10/17/2023
# 3           4          c4       P004      791.19          8/9/2024
# 4           5          c5       P005       20.75         5/21/2024
# ..        ...         ...        ...         ...               ...
# 594       595        c595       P595      247.03          3/8/2024
# 595       596        c596       P596      463.96         12/8/2023
# 596       597        c597       P597      844.83          6/1/2024
# 597       598        c598       P598      791.19         6/18/2024
# 598       599        c599       P599       20.75          7/9/2024
#
#       Payment Method customer_name   Customer Age  Gender Marital status  \
# 0        Credit Card      Hargrave             53    Male            Yes
# ...

# %%
products_new = final_dataset.isnull().sum()
products_new
# Out:
# Order_id              0
# customer ID           0
# product_id            0
# Unit Price           15
#  Aqcuisition Date     0
# Payment Method       17
# customer_name         0
#  Customer Age         0
# Gender                0
# Marital status        0
# Product_name          0
#  Product Quantity     0
# Product country      13
#  Delivery Method      0
# dtype: int64

# %%
sales['Unit Price'].fillna(sales['Unit Price'].mean(), inplace=True)
# Out:
# <ipython-input-47-4281c8e2fe09>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sales['Unit Price'].fillna(sales['Unit Price'].mean(), inplace=True)

# %%
#Before handling of missing values
products_new = final_dataset.isnull().sum()
products_new
# Out:
# Order_id              0
# customer ID           0
# product_id            0
# Unit Price           15
#  Aqcuisition Date     0
# Payment Method       17
# customer_name         0
#  Customer Age         0
# Gender                0
# Marital status        0
# Product_name          0
#  Product Quantity     0
# Product country      13
#  Delivery Method      0
# dtype: int64

# %% [markdown]
# **2.3**

# %%
#feature engineering scripts
#Handling missing values
mean_unit_price = final_dataset['Unit Price'].mean()
final_dataset['Unit Price'].fillna(mean_unit_price, inplace=True)
final_dataset['Unit Price']
# Out:
# <ipython-input-79-d3e08188aebc>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_dataset['Unit Price'].fillna(mean_unit_price, inplace=True)
# 0      791.19
# 1      247.03
# 2      463.96
# 3      791.19
# 4       20.75
#         ...
# 594    247.03
# 595    463.96
# 596    844.83
# 597    791.19
# 598     20.75
# Name: Unit Price, Length: 599, dtype: float64

# %%
mean_product_Q = final_dataset[' Product Quantity'].mean()
final_dataset[' Product Quantity'].fillna(mean_product_Q, inplace=True)
final_dataset[' Product Quantity']
# Out:
# <ipython-input-80-a402f3bd86f4>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_dataset[' Product Quantity'].fillna(mean_product_Q, inplace=True)
# 0      6
# 1      6
# 2      8
# 3      6
# 4      6
#       ..
# 594    1
# 595    1
# 596    3
# 597    2
# 598    1
# Name:  Product Quantity, Length: 599, dtype: int64

# %%
mean_payment_method = final_dataset['Payment Method'].mode()[0]
final_dataset['Payment Method'].fillna
final_dataset['Payment Method'].fillna(mean_payment_method, inplace=True)
final_dataset['Payment Method']
# Out:
# <ipython-input-81-22e8001e3521>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_dataset['Payment Method'].fillna(mean_payment_method, inplace=True)
# 0          Credit Card
# 1          Credit Card
# 2      Bank Withdrawal
# 3      Bank Withdrawal
# 4          Credit Card
#             ...
# 594        Credit Card
# 595        Credit Card
# 596    Bank Withdrawal
# 597    Bank Withdrawal
# 598        Credit Card
# Name: Payment Method, Length: 599, dtype: object

# %%
mean_product_country = final_dataset['Product country'].mode()[0]
final_dataset['Product country'].fillna
final_dataset['Product country'].fillna(mean_product_country , inplace=True)
final_dataset['Product country']
# Out:
# <ipython-input-82-715f713d8170>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_dataset['Product country'].fillna(mean_product_country , inplace=True)
# 0       France
# 1        Spain
# 2       France
# 3       France
# 4        Spain
#         ...
# 594      Spain
# 595    Germany
# 596      Spain
# 597    Germany
# 598    Germany
# Name: Product country, Length: 599, dtype: object

# %%
mean_total_aqcuisition_value = final_dataset['Total Aqcuisition Value'].mean()
final_dataset['Total Aqcuisition Value'].fillna(mean_total_aqcuisition_value , inplace=True)
final_dataset['Total Aqcuisition Value']
# Out:
# 0      4747.14
# 1      1482.18
# 2      3711.68
# 3      4747.14
# 4       124.50
#         ...
# 594     247.03
# 595     463.96
# 596    2534.49
# 597    1582.38
# 598      20.75
# Name: Total Aqcuisition Value, Length: 599, dtype: float64

# %%
#After handling missing values in final_dataset(merged dataset)
products_new = final_dataset.isnull().sum()
products_new
# Out:
# Order_id                   0
# customer ID                0
# product_id                 0
# Unit Price                 0
#  Aqcuisition Date          0
# Payment Method             0
# customer_name              0
#  Customer Age              0
# Gender                     0
# Marital status             0
# Product_name               0
#  Product Quantity          0
# Product country            0
#  Delivery Method           0
# Total Aqcuisition Value    0
# Age Range                  0
# dtype: int64

# %%
#feature engineering scripts
#Adapting new features for customer age
def age_range(age):
    if age < 30:
        return 'Young'
    elif age < 60:
        return 'Adult'
    else:
        return 'Late Adulthood'

final_dataset['Age Range'] = final_dataset[' Customer Age'].apply(age_range)
final_dataset
# Out:
#      Order_id customer ID product_id  Unit Price  Aqcuisition Date  \
# 0           1          c1       P001      791.19         3/20/2024
# 1           2          c2       P002      247.03         4/20/2024
# 2           3          c3       P003      463.96        10/17/2023
# 3           4          c4       P004      791.19          8/9/2024
# 4           5          c5       P005       20.75         5/21/2024
# ..        ...         ...        ...         ...               ...
# 594       595        c595       P595      247.03          3/8/2024
# 595       596        c596       P596      463.96         12/8/2023
# 596       597        c597       P597      844.83          6/1/2024
# 597       598        c598       P598      791.19         6/18/2024
# 598       599        c599       P599       20.75          7/9/2024
#
#       Payment Method customer_name   Customer Age  Gender Marital status  \
# 0        Credit Card      Hargrave             53    Male            Yes
# ...

# %%
#calculating total purchasing value
final_dataset['Total Aqcuisition Value'] = final_dataset['Unit Price'] * final_dataset[' Product Quantity']
final_dataset
# Out:
#      Order_id customer ID product_id  Unit Price  Aqcuisition Date  \
# 0           1          c1       P001      791.19         3/20/2024
# 1           2          c2       P002      247.03         4/20/2024
# 2           3          c3       P003      463.96        10/17/2023
# 3           4          c4       P004      791.19          8/9/2024
# 4           5          c5       P005       20.75         5/21/2024
# ..        ...         ...        ...         ...               ...
# 594       595        c595       P595      247.03          3/8/2024
# 595       596        c596       P596      463.96         12/8/2023
# 596       597        c597       P597      844.83          6/1/2024
# 597       598        c598       P598      791.19         6/18/2024
# 598       599        c599       P599       20.75          7/9/2024
#
#       Payment Method customer_name   Customer Age  Gender Marital status  \
# 0        Credit Card      Hargrave             53    Male            Yes
# ...

# %%
total_customer_sales = final_dataset.groupby('customer ID')['Total Aqcuisition Value'].sum()
total_customer_sales
# Out:
# customer ID
# c1       4747.140000
# c10     14846.720000
# c100    11563.801644
# c101     2890.950411
# c102    23127.603288
#             ...
# c95      4747.140000
# c96       124.500000
# c97      2490.000000
# c98     11135.040000
# c99      5928.720000
# Name: Total Aqcuisition Value, Length: 599, dtype: float64

# %% [markdown]
# **2.4**

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order_id                 599 non-null    int64
#  1   customer ID              599 non-null    object
#  2   product_id               599 non-null    object
#  3   Unit Price               599 non-null    float64
#  4    Aqcuisition Date        599 non-null    object
#  5   Payment Method           599 non-null    object
#  6   customer_name            599 non-null    object
#  7    Customer Age            599 non-null    int64
#  8   Gender                   599 non-null    object
#  9   Marital status           599 non-null    object
#  10  Product_name             599 non-null    object
#  11   Product Quantity        599 non-null    int64
#  12  Product country          599 non-null    object
#  13   Delivery Method         599 non-null    object
# ...

# %%
#statisctics for numerical variables
N_satistics = final_dataset[['Unit Price',' Customer Age',' Product Quantity','Total Aqcuisition Value']].describe()
N_satistics
# Out:
#        Unit Price   Customer Age   Product Quantity  Total Aqcuisition Value
# count  599.000000     599.000000         599.000000               599.000000
# mean   481.825068      47.721202          13.741235              6539.568225
# std    312.278089      19.895565          35.381317             22429.999496
# min     20.750000       0.000000         -24.000000            -18988.560000
# 25%    247.030000      31.000000           2.000000               463.960000
# 50%    463.960000      50.000000           6.000000              1582.380000
# 75%    791.190000      64.000000          12.000000              5068.980000
# max    844.830000      80.000000         432.000000            364966.560000

# %%
#statistic for categorical variables
C_satistics = final_dataset.describe(include='object')
C_satistics
# Out:
#        customer ID product_id  Aqcuisition Date   Payment Method  \
# count          599        599               599              599
# unique         599        599               304                3
# top             c1       P001         6/13/2024  Bank Withdrawal
# freq             1          1                 6              376
#
#        customer_name Gender Marital status Product_name Product country  \
# count            599    599            599          599             599
# unique           485      2              2            4               3
# top             Shih   Male             No   Smartphone          France
# freq               5    315            304          250             282
#
#         Delivery Method Age Range
# count               599       599
# unique                3         3
# top           Overnight     Adult
# freq                213       261

# %%
final_dataset_dp = len(final_dataset)
final_dataset_attributes = list(final_dataset)
final_dataset_data_type = final_dataset.dtypes

# %%
metadataf = pd.DataFrame({
    'Property': ['Number of DP - final_dataset','types of attributes - final_dataset', 'data type - final_dataset','Numerical variables - final_dataset','Categorical Variable - final_dataset'],
    'Value': [final_dataset_dp, final_dataset_attributes, final_dataset_data_type, N_satistics, C_satistics]
})

# %%
metadataf.to_csv('metadataf.csv', index=False)

# %% [markdown]
# **Task 03**

# %%
#Data loading SQL
import sqlite3 as sql

# %%
conn = sql.connect('final_dataset.db')
cur = conn.cursor()

# %%
final_dataset.to_sql('final_dataset',conn,if_exists='replace',index=False)
# Out:
# 599

# %%
conn.commit()
conn.close()
